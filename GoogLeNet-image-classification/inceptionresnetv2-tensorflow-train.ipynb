# %% [markdown]
# # InceptionResNetV2

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.callbacks import EarlyStopping
import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Ensure GPU is available and set memory growth
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Paths to training and validation data
train_path = "/kaggle/input/indian-birds/Birds_25/train"
val_path = "/kaggle/input/indian-birds/Birds_25/valid"

# %%
# Parameters
img_height, img_width = 128, 128
batch_size = 32

# %%
# Load datasets
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    val_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 30000 files belonging to 25 classes.
# Found 7500 files belonging to 25 classes.

# %%
# Print class names
class_names = train_ds.class_names
print(*class_names)
# Out:
# Asian-Green-Bee-Eater Brown-Headed-Barbet Cattle-Egret Common-Kingfisher Common-Myna Common-Rosefinch Common-Tailorbird Coppersmith-Barbet Forest-Wagtail Gray-Wagtail Hoopoe House-Crow Indian-Grey-Hornbill Indian-Peacock Indian-Pitta Indian-Roller Jungle-Babbler Northern-Lapwing Red-Wattled-Lapwing Ruddy-Shelduck Rufous-Treepie Sarus-Crane White-Breasted-Kingfisher White-Breasted-Waterhen White-Wagtail

# %%
import matplotlib.pyplot as plt

# Get a batch of images and labels from the training dataset
image_batch, label_batch = next(iter(train_ds))

# Define the number of samples to display
num_samples = 25  # Display 25 images (5x5 grid)
plt.figure(figsize=(15, 15))

for i in range(num_samples):
    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")

plt.show()

# %%
# Data augmentation
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

# %%
# Preprocess and optimize data loading
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Define the model
num_classes = len(class_names)

# Define the model
base_model = InceptionResNetV2(weights='imagenet', input_shape=(img_height, img_width, 3), include_top=False)
base_model.trainable = False  # Initially freeze the base model
# Build the model
model = models.Sequential([
    layers.Input(shape=(img_height, img_width, 3)),  # Define input shape
    data_augmentation,  # Apply augmentation first
    layers.Rescaling(1./255),  # Then rescale
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.Dense(num_classes, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_resnet_v2             │ (None, 2, 2, 1536)     │    54,336,736 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1536)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       196,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_203         │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         3,225 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,537,209 (208.04 MB)
#  Trainable params: 200,217 (782.10 KB)
#  Non-trainable params: 54,336,992 (207.28 MB)

# %%
# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# TensorBoard callback for visualization
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    filepath='/kaggle/working/checkpoint/InceptionResNetV2-checkpoint-{epoch:02d}-{val_loss:.2f}.keras',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    verbose=1
)

# %%
# Train the model
epochs = 150

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, tensorboard_callback, checkpoint_callback]
)
# Out:
# Epoch 1/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2587 - loss: 2.6593
# Epoch 1: val_loss improved from inf to 1.49594, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-01-1.50.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 157s 144ms/step - accuracy: 0.2588 - loss: 2.6588 - val_accuracy: 0.5623 - val_loss: 1.4959
# Epoch 2/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4984 - loss: 1.7047
# Epoch 2: val_loss improved from 1.49594 to 1.28005, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-02-1.28.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 86ms/step - accuracy: 0.4984 - loss: 1.7045 - val_accuracy: 0.6211 - val_loss: 1.2800
# Epoch 3/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5432 - loss: 1.5300
# Epoch 3: val_loss improved from 1.28005 to 1.19613, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-03-1.20.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 86ms/step - accuracy: 0.5432 - loss: 1.5300 - val_accuracy: 0.6423 - val_loss: 1.1961
# Epoch 4/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5732 - loss: 1.4278
# Epoch 4: val_loss improved from 1.19613 to 1.12524, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-04-1.13.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 86ms/step - accuracy: 0.5732 - loss: 1.4278 - val_accuracy: 0.6607 - val_loss: 1.1252
# Epoch 5/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5820 - loss: 1.3722
# Epoch 5: val_loss improved from 1.12524 to 1.09169, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-05-1.09.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 86ms/step - accuracy: 0.5821 - loss: 1.3722 - val_accuracy: 0.6733 - val_loss: 1.0917
# Epoch 6/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6026 - loss: 1.3175
# Epoch 6: val_loss improved from 1.09169 to 1.08307, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-06-1.08.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.6026 - loss: 1.3175 - val_accuracy: 0.6712 - val_loss: 1.0831
# Epoch 7/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6047 - loss: 1.2929
# Epoch 7: val_loss improved from 1.08307 to 1.04352, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-07-1.04.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 90ms/step - accuracy: 0.6047 - loss: 1.2929 - val_accuracy: 0.6832 - val_loss: 1.0435
# Epoch 8/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6146 - loss: 1.2652
# Epoch 8: val_loss improved from 1.04352 to 1.03135, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-08-1.03.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.6146 - loss: 1.2652 - val_accuracy: 0.6848 - val_loss: 1.0313
# Epoch 9/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6236 - loss: 1.2328
# Epoch 9: val_loss improved from 1.03135 to 1.01503, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-09-1.02.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 141s 87ms/step - accuracy: 0.6236 - loss: 1.2328 - val_accuracy: 0.6900 - val_loss: 1.0150
# Epoch 10/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6234 - loss: 1.2157
# Epoch 10: val_loss improved from 1.01503 to 0.99427, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-10-0.99.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.6234 - loss: 1.2157 - val_accuracy: 0.7004 - val_loss: 0.9943
# Epoch 11/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6314 - loss: 1.2043
# Epoch 11: val_loss improved from 0.99427 to 0.99036, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-11-0.99.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.6314 - loss: 1.2043 - val_accuracy: 0.6943 - val_loss: 0.9904
# Epoch 12/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6381 - loss: 1.1818
# Epoch 12: val_loss improved from 0.99036 to 0.97707, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-12-0.98.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.6381 - loss: 1.1818 - val_accuracy: 0.7036 - val_loss: 0.9771
# Epoch 13/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6392 - loss: 1.1698
# Epoch 13: val_loss improved from 0.97707 to 0.95560, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-13-0.96.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.6392 - loss: 1.1698 - val_accuracy: 0.7085 - val_loss: 0.9556
# Epoch 14/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6432 - loss: 1.1655
# Epoch 14: val_loss did not improve from 0.95560
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.6432 - loss: 1.1655 - val_accuracy: 0.7015 - val_loss: 0.9730
# Epoch 15/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6513 - loss: 1.1352
# Epoch 15: val_loss did not improve from 0.95560
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 80s 85ms/step - accuracy: 0.6513 - loss: 1.1352 - val_accuracy: 0.6988 - val_loss: 0.9595
# Epoch 16/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6522 - loss: 1.1311
# Epoch 16: val_loss improved from 0.95560 to 0.93047, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-16-0.93.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 90ms/step - accuracy: 0.6522 - loss: 1.1311 - val_accuracy: 0.7129 - val_loss: 0.9305
# Epoch 17/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6515 - loss: 1.1344
# Epoch 17: val_loss improved from 0.93047 to 0.91790, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-17-0.92.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.6515 - loss: 1.1344 - val_accuracy: 0.7191 - val_loss: 0.9179
# Epoch 18/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6551 - loss: 1.1132
# Epoch 18: val_loss did not improve from 0.91790
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 85ms/step - accuracy: 0.6551 - loss: 1.1132 - val_accuracy: 0.7085 - val_loss: 0.9343
# Epoch 19/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6575 - loss: 1.1141
# Epoch 19: val_loss did not improve from 0.91790
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 80s 85ms/step - accuracy: 0.6575 - loss: 1.1140 - val_accuracy: 0.7163 - val_loss: 0.9187
# Epoch 20/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6583 - loss: 1.0954
# Epoch 20: val_loss improved from 0.91790 to 0.89550, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-20-0.90.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 86ms/step - accuracy: 0.6583 - loss: 1.0954 - val_accuracy: 0.7252 - val_loss: 0.8955
# Epoch 21/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6601 - loss: 1.1007
# Epoch 21: val_loss did not improve from 0.89550
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.6601 - loss: 1.1007 - val_accuracy: 0.7149 - val_loss: 0.9142
# Epoch 22/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6655 - loss: 1.0680
# Epoch 22: val_loss did not improve from 0.89550
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.6655 - loss: 1.0680 - val_accuracy: 0.7220 - val_loss: 0.9156
# Epoch 23/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6695 - loss: 1.0710
# Epoch 23: val_loss improved from 0.89550 to 0.88929, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-23-0.89.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 88ms/step - accuracy: 0.6695 - loss: 1.0710 - val_accuracy: 0.7245 - val_loss: 0.8893
# Epoch 24/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6605 - loss: 1.0853
# Epoch 24: val_loss did not improve from 0.88929
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 80s 86ms/step - accuracy: 0.6605 - loss: 1.0853 - val_accuracy: 0.7251 - val_loss: 0.8991
# Epoch 25/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6686 - loss: 1.0685
# Epoch 25: val_loss improved from 0.88929 to 0.88720, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-25-0.89.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 91ms/step - accuracy: 0.6686 - loss: 1.0685 - val_accuracy: 0.7251 - val_loss: 0.8872
# Epoch 26/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6708 - loss: 1.0521
# Epoch 26: val_loss did not improve from 0.88720
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 140s 89ms/step - accuracy: 0.6708 - loss: 1.0521 - val_accuracy: 0.7216 - val_loss: 0.8890
# Epoch 27/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6730 - loss: 1.0587
# Epoch 27: val_loss improved from 0.88720 to 0.88209, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-27-0.88.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.6730 - loss: 1.0587 - val_accuracy: 0.7279 - val_loss: 0.8821
# Epoch 28/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6749 - loss: 1.0511
# Epoch 28: val_loss did not improve from 0.88209
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.6749 - loss: 1.0511 - val_accuracy: 0.7183 - val_loss: 0.9082
# Epoch 29/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6801 - loss: 1.0436
# Epoch 29: val_loss did not improve from 0.88209
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 86ms/step - accuracy: 0.6801 - loss: 1.0436 - val_accuracy: 0.7208 - val_loss: 0.8903
# Epoch 30/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6821 - loss: 1.0267
# Epoch 30: val_loss did not improve from 0.88209
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 80s 85ms/step - accuracy: 0.6821 - loss: 1.0267 - val_accuracy: 0.7179 - val_loss: 0.9050
# Epoch 31/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6819 - loss: 1.0208
# Epoch 31: val_loss did not improve from 0.88209
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.6819 - loss: 1.0208 - val_accuracy: 0.7191 - val_loss: 0.8913
# Epoch 32/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6817 - loss: 1.0234
# Epoch 32: val_loss improved from 0.88209 to 0.86534, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-32-0.87.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.6817 - loss: 1.0233 - val_accuracy: 0.7289 - val_loss: 0.8653
# Epoch 33/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6832 - loss: 1.0122
# Epoch 33: val_loss improved from 0.86534 to 0.86516, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-33-0.87.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.6832 - loss: 1.0122 - val_accuracy: 0.7272 - val_loss: 0.8652
# Epoch 34/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6879 - loss: 1.0108
# Epoch 34: val_loss did not improve from 0.86516
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 87ms/step - accuracy: 0.6879 - loss: 1.0108 - val_accuracy: 0.7305 - val_loss: 0.8706
# Epoch 35/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6841 - loss: 1.0182
# Epoch 35: val_loss did not improve from 0.86516
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 86ms/step - accuracy: 0.6841 - loss: 1.0182 - val_accuracy: 0.7293 - val_loss: 0.8704
# Epoch 36/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6877 - loss: 0.9967
# Epoch 36: val_loss did not improve from 0.86516
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 80s 85ms/step - accuracy: 0.6877 - loss: 0.9967 - val_accuracy: 0.7343 - val_loss: 0.8688
# Epoch 37/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6877 - loss: 1.0006
# Epoch 37: val_loss did not improve from 0.86516
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 88ms/step - accuracy: 0.6877 - loss: 1.0006 - val_accuracy: 0.7260 - val_loss: 0.8873
# Epoch 38/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6864 - loss: 1.0008
# Epoch 38: val_loss improved from 0.86516 to 0.84398, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-38-0.84.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 87ms/step - accuracy: 0.6864 - loss: 1.0008 - val_accuracy: 0.7409 - val_loss: 0.8440
# Epoch 39/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6922 - loss: 0.9909
# Epoch 39: val_loss did not improve from 0.84398
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 78s 84ms/step - accuracy: 0.6922 - loss: 0.9909 - val_accuracy: 0.7337 - val_loss: 0.8593
# Epoch 40/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6943 - loss: 0.9871
# Epoch 40: val_loss improved from 0.84398 to 0.82765, saving model to /kaggle/working/checkpoint/InceptionResNetV2-checkpoint-40-0.83.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 87ms/step - accuracy: 0.6943 - loss: 0.9871 - val_accuracy: 0.7457 - val_loss: 0.8277
# Epoch 41/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6914 - loss: 0.9807
# Epoch 41: val_loss did not improve from 0.82765
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.6914 - loss: 0.9807 - val_accuracy: 0.7309 - val_loss: 0.8594
# Epoch 42/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6929 - loss: 0.9723
# Epoch 42: val_loss did not improve from 0.82765
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.6929 - loss: 0.9723 - val_accuracy: 0.7341 - val_loss: 0.8589
# Epoch 43/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6905 - loss: 0.9818
# Epoch 43: val_loss did not improve from 0.82765
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.6905 - loss: 0.9818 - val_accuracy: 0.7368 - val_loss: 0.8391
# Epoch 44/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6958 - loss: 0.9671
# Epoch 44: val_loss did not improve from 0.82765
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 78s 84ms/step - accuracy: 0.6958 - loss: 0.9671 - val_accuracy: 0.7319 - val_loss: 0.8448
# Epoch 45/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7000 - loss: 0.9658
# Epoch 45: val_loss did not improve from 0.82765
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 78s 84ms/step - accuracy: 0.7000 - loss: 0.9658 - val_accuracy: 0.7388 - val_loss: 0.8397

# %%
# Save the final model (this will be the best model if early stopping is triggered)
model.save_weights('/kaggle/working/final_modelInceptionResNetV2.weights.h5')

# %%
# Attempt to save the model in HDF5 format
path ="/kaggle/working/final_modelInceptionResNetV2"
try:
    model.save(f'{path}.h5')
    print("Model saved successfully in HDF5 format.")
except Exception as e:
    print(f"Failed to save model in HDF5 format: {e}")
    print("Attempting to save model in Keras format...")
    try:
        model.save(f'{path}.keras')
        print("Model saved successfully in Keras format.")
    except Exception as e:
        print(f"Failed to save model in Keras format: {e}")
# Out:
# Failed to save model in HDF5 format: cannot pickle 'module' object
# Attempting to save model in Keras format...
# Model saved successfully in Keras format.

# %%
# Plot training & validation accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Evaluate the model
loss, accuracy = model.evaluate(val_ds)
print(f'Validation Accuracy: {accuracy:.2f}')
print(f'Validation loss: {loss:.2f}')
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.7440 - loss: 0.8253
# Validation Accuracy: 0.75
# Validation loss: 0.83

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Get the true labels and predictions
y_true = np.concatenate([y for x, y in val_ds], axis=0)
y_pred = np.argmax(model.predict(val_ds), axis=-1)

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Classification report
class_report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:\n", class_report)
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step
# Classification Report:
#                             precision    recall  f1-score   support
#
#     Asian-Green-Bee-Eater       0.71      0.83      0.77       300
#       Brown-Headed-Barbet       0.59      0.59      0.59       300
#              Cattle-Egret       0.82      0.88      0.85       300
#         Common-Kingfisher       0.83      0.77      0.80       300
#               Common-Myna       0.72      0.79      0.76       300
#          Common-Rosefinch       0.60      0.59      0.59       300
#         Common-Tailorbird       0.63      0.63      0.63       300
#        Coppersmith-Barbet       0.66      0.63      0.64       300
#            Forest-Wagtail       0.78      0.79      0.79       300
#              Gray-Wagtail       0.80      0.74      0.77       300
#                    Hoopoe       0.88      0.88      0.88       300
#                House-Crow       0.75      0.74      0.75       300
#      Indian-Grey-Hornbill       0.63      0.66      0.65       300
#            Indian-Peacock       0.77      0.86      0.81       300
#              Indian-Pitta       0.82      0.76      0.79       300
#             Indian-Roller       0.81      0.60      0.69       300
#            Jungle-Babbler       0.72      0.73      0.73       300
#          Northern-Lapwing       0.72      0.72      0.72       300
#       Red-Wattled-Lapwing       0.70      0.74      0.72       300
#            Ruddy-Shelduck       0.79      0.86      0.82       300
#            Rufous-Treepie       0.75      0.69      0.72       300
#               Sarus-Crane       0.80      0.78      0.79       300
# White-Breasted-Kingfisher       0.82      0.85      0.83       300
#   White-Breasted-Waterhen       0.72      0.66      0.69       300
#             White-Wagtail       0.82      0.88      0.85       300
#
#                  accuracy                           0.75      7500
#                 macro avg       0.75      0.75      0.74      7500
#              weighted avg       0.75      0.75      0.74      7500
