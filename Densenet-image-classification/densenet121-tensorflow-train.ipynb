# %% [markdown]
# # Densenet121

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.callbacks import EarlyStopping
import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2024-08-20 07:16:07.798904: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-20 07:16:07.799017: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-20 07:16:07.947290: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Ensure GPU is available and set memory growth
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Paths to training and validation data
train_path = "/kaggle/input/indian-birds/Birds_25/train"
val_path = "/kaggle/input/indian-birds/Birds_25/valid"

# %%
# Parameters
img_height, img_width = 128, 128
batch_size = 32

# %%
# Load datasets
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    val_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 30000 files belonging to 25 classes.
# Found 7500 files belonging to 25 classes.

# %%
# Print class names
class_names = train_ds.class_names
print(*class_names)
# Out:
# Asian-Green-Bee-Eater Brown-Headed-Barbet Cattle-Egret Common-Kingfisher Common-Myna Common-Rosefinch Common-Tailorbird Coppersmith-Barbet Forest-Wagtail Gray-Wagtail Hoopoe House-Crow Indian-Grey-Hornbill Indian-Peacock Indian-Pitta Indian-Roller Jungle-Babbler Northern-Lapwing Red-Wattled-Lapwing Ruddy-Shelduck Rufous-Treepie Sarus-Crane White-Breasted-Kingfisher White-Breasted-Waterhen White-Wagtail

# %%
import matplotlib.pyplot as plt

# Get a batch of images and labels from the training dataset
image_batch, label_batch = next(iter(train_ds))

# Define the number of samples to display
num_samples = 25  # Display 25 images (5x5 grid)
plt.figure(figsize=(15, 15))

for i in range(num_samples):
    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")

plt.show()

# %%
# Data augmentation
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

# %%
# Preprocess and optimize data loading
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Define the model
num_classes = len(class_names)

# Define the model
base_model = DenseNet121(weights='imagenet', input_shape=(img_height, img_width, 3), include_top=False)
base_model.trainable = False  # Initially freeze the base model
# Build the model
model = models.Sequential([
    layers.Input(shape=(img_height, img_width, 3)),  # Define input shape
    data_augmentation,  # Apply augmentation first
    layers.Rescaling(1./255),  # Then rescale
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.Dense(num_classes, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 4, 4, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         3,225 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,172,441 (27.36 MB)
#  Trainable params: 134,681 (526.10 KB)
#  Non-trainable params: 7,037,760 (26.85 MB)

# %%
# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# TensorBoard callback for visualization
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    filepath='/kaggle/working/checkpoint/Densenet121-checkpoint-{epoch:02d}-{val_loss:.2f}.keras',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    verbose=1
)

# %%
# Train the model
epochs = 150

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, tensorboard_callback, checkpoint_callback]
)
# Out:
# Epoch 1/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.2419 - loss: 2.7743
# Epoch 1: val_loss improved from inf to 1.27877, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-01-1.28.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 156s 145ms/step - accuracy: 0.2420 - loss: 2.7737 - val_accuracy: 0.6199 - val_loss: 1.2788
# Epoch 2/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5619 - loss: 1.4941
# Epoch 2: val_loss improved from 1.27877 to 0.96118, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-02-0.96.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 54s 58ms/step - accuracy: 0.5619 - loss: 1.4940 - val_accuracy: 0.7088 - val_loss: 0.9612
# Epoch 3/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6239 - loss: 1.2647
# Epoch 3: val_loss improved from 0.96118 to 0.85398, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-03-0.85.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 54s 58ms/step - accuracy: 0.6239 - loss: 1.2646 - val_accuracy: 0.7380 - val_loss: 0.8540
# Epoch 4/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6604 - loss: 1.1423
# Epoch 4: val_loss improved from 0.85398 to 0.78603, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-04-0.79.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 54s 57ms/step - accuracy: 0.6604 - loss: 1.1422 - val_accuracy: 0.7597 - val_loss: 0.7860
# Epoch 5/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6729 - loss: 1.0849
# Epoch 5: val_loss improved from 0.78603 to 0.75070, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-05-0.75.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 58ms/step - accuracy: 0.6729 - loss: 1.0849 - val_accuracy: 0.7716 - val_loss: 0.7507
# Epoch 6/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6911 - loss: 1.0248
# Epoch 6: val_loss improved from 0.75070 to 0.72906, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-06-0.73.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.6911 - loss: 1.0248 - val_accuracy: 0.7771 - val_loss: 0.7291
# Epoch 7/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6979 - loss: 0.9874
# Epoch 7: val_loss improved from 0.72906 to 0.70542, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-07-0.71.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.6979 - loss: 0.9874 - val_accuracy: 0.7892 - val_loss: 0.7054
# Epoch 8/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7077 - loss: 0.9588
# Epoch 8: val_loss improved from 0.70542 to 0.69736, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-08-0.70.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.7077 - loss: 0.9588 - val_accuracy: 0.7855 - val_loss: 0.6974
# Epoch 9/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7146 - loss: 0.9307
# Epoch 9: val_loss improved from 0.69736 to 0.68290, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-09-0.68.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 59ms/step - accuracy: 0.7146 - loss: 0.9306 - val_accuracy: 0.7929 - val_loss: 0.6829
# Epoch 10/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7138 - loss: 0.9306
# Epoch 10: val_loss did not improve from 0.68290
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 54s 57ms/step - accuracy: 0.7138 - loss: 0.9306 - val_accuracy: 0.7896 - val_loss: 0.6865
# Epoch 11/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7192 - loss: 0.9167
# Epoch 11: val_loss improved from 0.68290 to 0.67563, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-11-0.68.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 59ms/step - accuracy: 0.7192 - loss: 0.9167 - val_accuracy: 0.7929 - val_loss: 0.6756
# Epoch 12/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7226 - loss: 0.8969
# Epoch 12: val_loss improved from 0.67563 to 0.66833, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-12-0.67.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.7226 - loss: 0.8969 - val_accuracy: 0.7944 - val_loss: 0.6683
# Epoch 13/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7243 - loss: 0.8877
# Epoch 13: val_loss improved from 0.66833 to 0.65608, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-13-0.66.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.7243 - loss: 0.8877 - val_accuracy: 0.7997 - val_loss: 0.6561
# Epoch 14/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7280 - loss: 0.8882
# Epoch 14: val_loss improved from 0.65608 to 0.65516, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-14-0.66.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.7280 - loss: 0.8882 - val_accuracy: 0.8004 - val_loss: 0.6552
# Epoch 15/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7364 - loss: 0.8588
# Epoch 15: val_loss improved from 0.65516 to 0.64204, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-15-0.64.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.7364 - loss: 0.8588 - val_accuracy: 0.8031 - val_loss: 0.6420
# Epoch 16/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7370 - loss: 0.8603
# Epoch 16: val_loss did not improve from 0.64204
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 53s 57ms/step - accuracy: 0.7370 - loss: 0.8603 - val_accuracy: 0.8045 - val_loss: 0.6436
# Epoch 17/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7429 - loss: 0.8405
# Epoch 17: val_loss improved from 0.64204 to 0.62984, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-17-0.63.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.7429 - loss: 0.8405 - val_accuracy: 0.8033 - val_loss: 0.6298
# Epoch 18/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7378 - loss: 0.8412
# Epoch 18: val_loss did not improve from 0.62984
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 53s 57ms/step - accuracy: 0.7378 - loss: 0.8412 - val_accuracy: 0.8037 - val_loss: 0.6391
# Epoch 19/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7389 - loss: 0.8348
# Epoch 19: val_loss did not improve from 0.62984
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 53s 57ms/step - accuracy: 0.7389 - loss: 0.8348 - val_accuracy: 0.8055 - val_loss: 0.6362
# Epoch 20/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7451 - loss: 0.8209
# Epoch 20: val_loss did not improve from 0.62984
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 53s 57ms/step - accuracy: 0.7451 - loss: 0.8209 - val_accuracy: 0.8060 - val_loss: 0.6309
# Epoch 21/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7473 - loss: 0.8168
# Epoch 21: val_loss improved from 0.62984 to 0.62675, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-21-0.63.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.7473 - loss: 0.8168 - val_accuracy: 0.8071 - val_loss: 0.6267
# Epoch 22/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7471 - loss: 0.8090
# Epoch 22: val_loss improved from 0.62675 to 0.62505, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-22-0.63.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 59ms/step - accuracy: 0.7471 - loss: 0.8090 - val_accuracy: 0.8087 - val_loss: 0.6251
# Epoch 23/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7430 - loss: 0.8214
# Epoch 23: val_loss did not improve from 0.62505
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 53s 57ms/step - accuracy: 0.7430 - loss: 0.8214 - val_accuracy: 0.8047 - val_loss: 0.6322
# Epoch 24/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7480 - loss: 0.8056
# Epoch 24: val_loss did not improve from 0.62505
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 53s 57ms/step - accuracy: 0.7480 - loss: 0.8056 - val_accuracy: 0.8067 - val_loss: 0.6274
# Epoch 25/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7526 - loss: 0.7951
# Epoch 25: val_loss did not improve from 0.62505
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 53s 57ms/step - accuracy: 0.7526 - loss: 0.7951 - val_accuracy: 0.8049 - val_loss: 0.6340
# Epoch 26/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7486 - loss: 0.7971
# Epoch 26: val_loss improved from 0.62505 to 0.62434, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-26-0.62.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.7486 - loss: 0.7971 - val_accuracy: 0.8077 - val_loss: 0.6243
# Epoch 27/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7501 - loss: 0.7935
# Epoch 27: val_loss improved from 0.62434 to 0.62094, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-27-0.62.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.7501 - loss: 0.7935 - val_accuracy: 0.8104 - val_loss: 0.6209
# Epoch 28/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7546 - loss: 0.7855
# Epoch 28: val_loss did not improve from 0.62094
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 53s 57ms/step - accuracy: 0.7546 - loss: 0.7855 - val_accuracy: 0.8087 - val_loss: 0.6246
# Epoch 29/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7599 - loss: 0.7748
# Epoch 29: val_loss improved from 0.62094 to 0.61403, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-29-0.61.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.7599 - loss: 0.7748 - val_accuracy: 0.8097 - val_loss: 0.6140
# Epoch 30/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7569 - loss: 0.7730
# Epoch 30: val_loss improved from 0.61403 to 0.61189, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-30-0.61.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 58ms/step - accuracy: 0.7569 - loss: 0.7730 - val_accuracy: 0.8104 - val_loss: 0.6119
# Epoch 31/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7606 - loss: 0.7662
# Epoch 31: val_loss did not improve from 0.61189
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 54s 57ms/step - accuracy: 0.7606 - loss: 0.7662 - val_accuracy: 0.8085 - val_loss: 0.6134
# Epoch 32/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7563 - loss: 0.7724
# Epoch 32: val_loss did not improve from 0.61189
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 53s 57ms/step - accuracy: 0.7563 - loss: 0.7724 - val_accuracy: 0.8075 - val_loss: 0.6252
# Epoch 33/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7595 - loss: 0.7661
# Epoch 33: val_loss improved from 0.61189 to 0.60291, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-33-0.60.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 54s 58ms/step - accuracy: 0.7595 - loss: 0.7661 - val_accuracy: 0.8136 - val_loss: 0.6029
# Epoch 34/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7607 - loss: 0.7654
# Epoch 34: val_loss improved from 0.60291 to 0.59884, saving model to /kaggle/working/checkpoint/Densenet121-checkpoint-34-0.60.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 54s 58ms/step - accuracy: 0.7607 - loss: 0.7654 - val_accuracy: 0.8141 - val_loss: 0.5988
# Epoch 35/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7584 - loss: 0.7554
# Epoch 35: val_loss did not improve from 0.59884
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 53s 57ms/step - accuracy: 0.7584 - loss: 0.7554 - val_accuracy: 0.8031 - val_loss: 0.6235
# Epoch 36/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7622 - loss: 0.7590
# Epoch 36: val_loss did not improve from 0.59884
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 52s 55ms/step - accuracy: 0.7622 - loss: 0.7590 - val_accuracy: 0.8135 - val_loss: 0.6042
# Epoch 37/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7672 - loss: 0.7468
# Epoch 37: val_loss did not improve from 0.59884
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 52s 55ms/step - accuracy: 0.7672 - loss: 0.7468 - val_accuracy: 0.8100 - val_loss: 0.6031
# Epoch 38/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7686 - loss: 0.7412
# Epoch 38: val_loss did not improve from 0.59884
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 51s 55ms/step - accuracy: 0.7686 - loss: 0.7412 - val_accuracy: 0.8109 - val_loss: 0.6068
# Epoch 39/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7629 - loss: 0.7485
# Epoch 39: val_loss did not improve from 0.59884
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 51s 54ms/step - accuracy: 0.7629 - loss: 0.7485 - val_accuracy: 0.8117 - val_loss: 0.6015

# %%
# Save the final model (this will be the best model if early stopping is triggered)
model.save_weights('/kaggle/working/final_modelDensenet121.weights.h5')

# %%
# Attempt to save the model in HDF5 format
path ="/kaggle/working/final_modelDensenet121"
try:
    model.save(f'{path}.h5')
    print("Model saved successfully in HDF5 format.")
except Exception as e:
    print(f"Failed to save model in HDF5 format: {e}")
    print("Attempting to save model in Keras format...")
    try:
        model.save(f'{path}.keras')
        print("Model saved successfully in Keras format.")
    except Exception as e:
        print(f"Failed to save model in Keras format: {e}")
# Out:
# Failed to save model in HDF5 format: cannot pickle 'module' object
# Attempting to save model in Keras format...
# Model saved successfully in Keras format.

# %%
# Plot training & validation accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Evaluate the model
loss, accuracy = model.evaluate(val_ds)
print(f'Validation Accuracy: {accuracy:.2f}')
print(f'Validation loss: {loss:.2f}')
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.8158 - loss: 0.6003
# Validation Accuracy: 0.81
# Validation loss: 0.60

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Get the true labels and predictions
y_true = np.concatenate([y for x, y in val_ds], axis=0)
y_pred = np.argmax(model.predict(val_ds), axis=-1)

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Classification report
class_report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:\n", class_report)
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step
# Classification Report:
#                             precision    recall  f1-score   support
#
#     Asian-Green-Bee-Eater       0.85      0.86      0.85       300
#       Brown-Headed-Barbet       0.73      0.68      0.70       300
#              Cattle-Egret       0.96      0.91      0.93       300
#         Common-Kingfisher       0.91      0.85      0.88       300
#               Common-Myna       0.84      0.83      0.83       300
#          Common-Rosefinch       0.68      0.76      0.71       300
#         Common-Tailorbird       0.79      0.64      0.71       300
#        Coppersmith-Barbet       0.76      0.77      0.76       300
#            Forest-Wagtail       0.83      0.76      0.80       300
#              Gray-Wagtail       0.83      0.85      0.84       300
#                    Hoopoe       0.88      0.92      0.90       300
#                House-Crow       0.76      0.82      0.79       300
#      Indian-Grey-Hornbill       0.67      0.73      0.70       300
#            Indian-Peacock       0.84      0.89      0.87       300
#              Indian-Pitta       0.83      0.89      0.86       300
#             Indian-Roller       0.86      0.76      0.81       300
#            Jungle-Babbler       0.75      0.85      0.80       300
#          Northern-Lapwing       0.72      0.82      0.77       300
#       Red-Wattled-Lapwing       0.87      0.79      0.83       300
#            Ruddy-Shelduck       0.87      0.90      0.88       300
#            Rufous-Treepie       0.83      0.72      0.77       300
#               Sarus-Crane       0.86      0.87      0.87       300
# White-Breasted-Kingfisher       0.92      0.86      0.89       300
#   White-Breasted-Waterhen       0.82      0.68      0.75       300
#             White-Wagtail       0.77      0.94      0.84       300
#
#                  accuracy                           0.81      7500
#                 macro avg       0.82      0.81      0.81      7500
#              weighted avg       0.82      0.81      0.81      7500
