# %% [markdown]
# # DenseNet201

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.callbacks import EarlyStopping
import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2024-08-20 08:51:08.115924: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-20 08:51:08.116022: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-20 08:51:08.249736: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Ensure GPU is available and set memory growth
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Paths to training and validation data
train_path = "/kaggle/input/indian-birds/Birds_25/train"
val_path = "/kaggle/input/indian-birds/Birds_25/valid"

# %%
# Parameters
img_height, img_width = 128, 128
batch_size = 32

# %%
# Load datasets
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    val_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 30000 files belonging to 25 classes.
# Found 7500 files belonging to 25 classes.

# %%
# Print class names
class_names = train_ds.class_names
print(*class_names)
# Out:
# Asian-Green-Bee-Eater Brown-Headed-Barbet Cattle-Egret Common-Kingfisher Common-Myna Common-Rosefinch Common-Tailorbird Coppersmith-Barbet Forest-Wagtail Gray-Wagtail Hoopoe House-Crow Indian-Grey-Hornbill Indian-Peacock Indian-Pitta Indian-Roller Jungle-Babbler Northern-Lapwing Red-Wattled-Lapwing Ruddy-Shelduck Rufous-Treepie Sarus-Crane White-Breasted-Kingfisher White-Breasted-Waterhen White-Wagtail

# %%
import matplotlib.pyplot as plt

# Get a batch of images and labels from the training dataset
image_batch, label_batch = next(iter(train_ds))

# Define the number of samples to display
num_samples = 25  # Display 25 images (5x5 grid)
plt.figure(figsize=(15, 15))

for i in range(num_samples):
    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")

plt.show()

# %%
# Data augmentation
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

# %%
# Preprocess and optimize data loading
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Define the model
num_classes = len(class_names)

# Define the model
base_model = DenseNet201(weights='imagenet', input_shape=(img_height, img_width, 3), include_top=False)
base_model.trainable = False  # Initially freeze the base model
# Build the model
model = models.Sequential([
    layers.Input(shape=(img_height, img_width, 3)),  # Define input shape
    data_augmentation,  # Apply augmentation first
    layers.Rescaling(1./255),  # Then rescale
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.Dense(num_classes, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet201 (Functional)        │ (None, 4, 4, 1920)     │    18,321,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1920)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       245,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         3,225 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,571,609 (70.85 MB)
#  Trainable params: 249,369 (974.10 KB)
#  Non-trainable params: 18,322,240 (69.89 MB)

# %%
# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# TensorBoard callback for visualization
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    filepath='/kaggle/working/checkpoint/Densenet201-checkpoint-{epoch:02d}-{val_loss:.2f}.keras',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    verbose=1
)

# %%
# Train the model
epochs = 150

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, tensorboard_callback, checkpoint_callback]
)
# Out:
# Epoch 1/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2763 - loss: 2.6072
# Epoch 1: val_loss improved from inf to 1.08833, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-01-1.09.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 185s 166ms/step - accuracy: 0.2764 - loss: 2.6067 - val_accuracy: 0.6773 - val_loss: 1.0883
# Epoch 2/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5962 - loss: 1.3911
# Epoch 2: val_loss improved from 1.08833 to 0.83172, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-02-0.83.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.5962 - loss: 1.3910 - val_accuracy: 0.7536 - val_loss: 0.8317
# Epoch 3/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6569 - loss: 1.1633
# Epoch 3: val_loss improved from 0.83172 to 0.74564, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-03-0.75.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.6569 - loss: 1.1632 - val_accuracy: 0.7793 - val_loss: 0.7456
# Epoch 4/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6876 - loss: 1.0495
# Epoch 4: val_loss improved from 0.74564 to 0.69539, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-04-0.70.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.6876 - loss: 1.0495 - val_accuracy: 0.7927 - val_loss: 0.6954
# Epoch 5/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7042 - loss: 0.9800
# Epoch 5: val_loss improved from 0.69539 to 0.65113, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-05-0.65.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 86s 91ms/step - accuracy: 0.7042 - loss: 0.9800 - val_accuracy: 0.8037 - val_loss: 0.6511
# Epoch 6/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7201 - loss: 0.9269
# Epoch 6: val_loss improved from 0.65113 to 0.64004, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-06-0.64.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 86s 92ms/step - accuracy: 0.7201 - loss: 0.9269 - val_accuracy: 0.8021 - val_loss: 0.6400
# Epoch 7/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7330 - loss: 0.8898
# Epoch 7: val_loss improved from 0.64004 to 0.62246, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-07-0.62.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 90ms/step - accuracy: 0.7330 - loss: 0.8898 - val_accuracy: 0.8083 - val_loss: 0.6225
# Epoch 8/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7382 - loss: 0.8585
# Epoch 8: val_loss improved from 0.62246 to 0.60990, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-08-0.61.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 90ms/step - accuracy: 0.7382 - loss: 0.8585 - val_accuracy: 0.8128 - val_loss: 0.6099
# Epoch 9/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7392 - loss: 0.8486
# Epoch 9: val_loss improved from 0.60990 to 0.59078, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-09-0.59.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 90ms/step - accuracy: 0.7392 - loss: 0.8485 - val_accuracy: 0.8201 - val_loss: 0.5908
# Epoch 10/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7448 - loss: 0.8207
# Epoch 10: val_loss improved from 0.59078 to 0.58657, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-10-0.59.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.7448 - loss: 0.8207 - val_accuracy: 0.8236 - val_loss: 0.5866
# Epoch 11/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7485 - loss: 0.8105
# Epoch 11: val_loss did not improve from 0.58657
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 87ms/step - accuracy: 0.7485 - loss: 0.8105 - val_accuracy: 0.8221 - val_loss: 0.5894
# Epoch 12/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7497 - loss: 0.7990
# Epoch 12: val_loss improved from 0.58657 to 0.58188, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-12-0.58.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.7497 - loss: 0.7990 - val_accuracy: 0.8275 - val_loss: 0.5819
# Epoch 13/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7570 - loss: 0.7860
# Epoch 13: val_loss improved from 0.58188 to 0.57406, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-13-0.57.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.7570 - loss: 0.7860 - val_accuracy: 0.8253 - val_loss: 0.5741
# Epoch 14/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7568 - loss: 0.7732
# Epoch 14: val_loss did not improve from 0.57406
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 87ms/step - accuracy: 0.7568 - loss: 0.7732 - val_accuracy: 0.8233 - val_loss: 0.5765
# Epoch 15/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7636 - loss: 0.7590
# Epoch 15: val_loss improved from 0.57406 to 0.56696, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-15-0.57.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 90ms/step - accuracy: 0.7636 - loss: 0.7590 - val_accuracy: 0.8291 - val_loss: 0.5670
# Epoch 16/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7641 - loss: 0.7536
# Epoch 16: val_loss improved from 0.56696 to 0.55845, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-16-0.56.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 90ms/step - accuracy: 0.7641 - loss: 0.7536 - val_accuracy: 0.8303 - val_loss: 0.5585
# Epoch 17/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7680 - loss: 0.7438
# Epoch 17: val_loss improved from 0.55845 to 0.54753, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-17-0.55.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.7680 - loss: 0.7438 - val_accuracy: 0.8332 - val_loss: 0.5475
# Epoch 18/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7696 - loss: 0.7386
# Epoch 18: val_loss did not improve from 0.54753
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 86ms/step - accuracy: 0.7696 - loss: 0.7386 - val_accuracy: 0.8308 - val_loss: 0.5543
# Epoch 19/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7729 - loss: 0.7248
# Epoch 19: val_loss did not improve from 0.54753
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 88ms/step - accuracy: 0.7729 - loss: 0.7248 - val_accuracy: 0.8304 - val_loss: 0.5538
# Epoch 20/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7708 - loss: 0.7270
# Epoch 20: val_loss did not improve from 0.54753
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 87ms/step - accuracy: 0.7708 - loss: 0.7270 - val_accuracy: 0.8325 - val_loss: 0.5523
# Epoch 21/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7752 - loss: 0.7233
# Epoch 21: val_loss improved from 0.54753 to 0.53583, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-21-0.54.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.7752 - loss: 0.7233 - val_accuracy: 0.8359 - val_loss: 0.5358
# Epoch 22/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7747 - loss: 0.7222
# Epoch 22: val_loss did not improve from 0.53583
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.7747 - loss: 0.7222 - val_accuracy: 0.8364 - val_loss: 0.5424
# Epoch 23/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7758 - loss: 0.7122
# Epoch 23: val_loss did not improve from 0.53583
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.7758 - loss: 0.7122 - val_accuracy: 0.8340 - val_loss: 0.5415
# Epoch 24/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7794 - loss: 0.7049
# Epoch 24: val_loss improved from 0.53583 to 0.52597, saving model to /kaggle/working/checkpoint/Densenet201-checkpoint-24-0.53.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 90ms/step - accuracy: 0.7794 - loss: 0.7049 - val_accuracy: 0.8392 - val_loss: 0.5260
# Epoch 25/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7820 - loss: 0.6900
# Epoch 25: val_loss did not improve from 0.52597
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 91ms/step - accuracy: 0.7820 - loss: 0.6900 - val_accuracy: 0.8355 - val_loss: 0.5402
# Epoch 26/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7821 - loss: 0.6897
# Epoch 26: val_loss did not improve from 0.52597
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 90ms/step - accuracy: 0.7821 - loss: 0.6897 - val_accuracy: 0.8355 - val_loss: 0.5441
# Epoch 27/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7823 - loss: 0.6906
# Epoch 27: val_loss did not improve from 0.52597
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.7823 - loss: 0.6906 - val_accuracy: 0.8333 - val_loss: 0.5438
# Epoch 28/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7825 - loss: 0.6809
# Epoch 28: val_loss did not improve from 0.52597
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 88ms/step - accuracy: 0.7825 - loss: 0.6809 - val_accuracy: 0.8344 - val_loss: 0.5412
# Epoch 29/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7873 - loss: 0.6788
# Epoch 29: val_loss did not improve from 0.52597
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.7873 - loss: 0.6788 - val_accuracy: 0.8348 - val_loss: 0.5399

# %%
# Save the final model (this will be the best model if early stopping is triggered)
model.save_weights('/kaggle/working/final_modelDensenet201.weights.h5')

# %%
# Attempt to save the model in HDF5 format
path ="/kaggle/working/final_modelDensenet201"
try:
    model.save(f'{path}.h5')
    print("Model saved successfully in HDF5 format.")
except Exception as e:
    print(f"Failed to save model in HDF5 format: {e}")
    print("Attempting to save model in Keras format...")
    try:
        model.save(f'{path}.keras')
        print("Model saved successfully in Keras format.")
    except Exception as e:
        print(f"Failed to save model in Keras format: {e}")
# Out:
# Failed to save model in HDF5 format: cannot pickle 'module' object
# Attempting to save model in Keras format...
# Model saved successfully in Keras format.

# %%
# Plot training & validation accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Evaluate the model
loss, accuracy = model.evaluate(val_ds)
print(f'Validation Accuracy: {accuracy:.2f}')
print(f'Validation loss: {loss:.2f}')
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 14s 62ms/step - accuracy: 0.8462 - loss: 0.5186
# Validation Accuracy: 0.84
# Validation loss: 0.53

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Get the true labels and predictions
y_true = np.concatenate([y for x, y in val_ds], axis=0)
y_pred = np.argmax(model.predict(val_ds), axis=-1)

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Classification report
class_report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:\n", class_report)
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step
# Classification Report:
#                             precision    recall  f1-score   support
#
#     Asian-Green-Bee-Eater       0.82      0.88      0.85       300
#       Brown-Headed-Barbet       0.75      0.70      0.73       300
#              Cattle-Egret       0.93      0.94      0.94       300
#         Common-Kingfisher       0.95      0.84      0.89       300
#               Common-Myna       0.81      0.89      0.85       300
#          Common-Rosefinch       0.68      0.80      0.74       300
#         Common-Tailorbird       0.85      0.67      0.75       300
#        Coppersmith-Barbet       0.80      0.83      0.82       300
#            Forest-Wagtail       0.89      0.80      0.84       300
#              Gray-Wagtail       0.90      0.88      0.89       300
#                    Hoopoe       0.95      0.87      0.91       300
#                House-Crow       0.80      0.82      0.81       300
#      Indian-Grey-Hornbill       0.68      0.86      0.76       300
#            Indian-Peacock       0.88      0.91      0.89       300
#              Indian-Pitta       0.88      0.86      0.87       300
#             Indian-Roller       0.86      0.83      0.84       300
#            Jungle-Babbler       0.82      0.82      0.82       300
#          Northern-Lapwing       0.78      0.83      0.81       300
#       Red-Wattled-Lapwing       0.85      0.82      0.83       300
#            Ruddy-Shelduck       0.91      0.88      0.90       300
#            Rufous-Treepie       0.83      0.82      0.83       300
#               Sarus-Crane       0.83      0.87      0.85       300
# White-Breasted-Kingfisher       0.96      0.89      0.92       300
#   White-Breasted-Waterhen       0.86      0.77      0.81       300
#             White-Wagtail       0.82      0.89      0.86       300
#
#                  accuracy                           0.84      7500
#                 macro avg       0.84      0.84      0.84      7500
#              weighted avg       0.84      0.84      0.84      7500
