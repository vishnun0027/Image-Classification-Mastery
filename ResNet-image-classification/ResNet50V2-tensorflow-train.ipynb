# %% [markdown]
# # ResNet50V2

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.callbacks import EarlyStopping
import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Ensure GPU is available and set memory growth
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Paths to training and validation data
train_path = "/kaggle/input/indian-birds/Birds_25/train"
val_path = "/kaggle/input/indian-birds/Birds_25/valid"

# %%
# Parameters
img_height, img_width = 128, 128
batch_size = 32

# %%
# Load datasets
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    val_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 30000 files belonging to 25 classes.
# Found 7500 files belonging to 25 classes.

# %%
# Print class names
class_names = train_ds.class_names
print(*class_names)
# Out:
# Asian-Green-Bee-Eater Brown-Headed-Barbet Cattle-Egret Common-Kingfisher Common-Myna Common-Rosefinch Common-Tailorbird Coppersmith-Barbet Forest-Wagtail Gray-Wagtail Hoopoe House-Crow Indian-Grey-Hornbill Indian-Peacock Indian-Pitta Indian-Roller Jungle-Babbler Northern-Lapwing Red-Wattled-Lapwing Ruddy-Shelduck Rufous-Treepie Sarus-Crane White-Breasted-Kingfisher White-Breasted-Waterhen White-Wagtail

# %%
import matplotlib.pyplot as plt

# Get a batch of images and labels from the training dataset
image_batch, label_batch = next(iter(train_ds))

# Define the number of samples to display
num_samples = 25  # Display 25 images (5x5 grid)
plt.figure(figsize=(15, 15))

for i in range(num_samples):
    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")

plt.show()

# %%
# Data augmentation
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

# %%
# Preprocess and optimize data loading
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Define the model
num_classes = len(class_names)

# Define the model
base_model = ResNet50V2(weights='imagenet', input_shape=(img_height, img_width, 3), include_top=False)
base_model.trainable = False  # Initially freeze the base model
# Build the model
model = models.Sequential([
    layers.Input(shape=(img_height, img_width, 3)),  # Define input shape
    data_augmentation,  # Apply augmentation first
    layers.Rescaling(1./255),  # Then rescale
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.Dense(num_classes, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50v2 (Functional)         │ (None, 4, 4, 2048)     │    23,564,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         3,225 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,830,809 (90.91 MB)
#  Trainable params: 265,753 (1.01 MB)
#  Non-trainable params: 23,565,056 (89.89 MB)

# %%
# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# TensorBoard callback for visualization
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    filepath='/kaggle/working/checkpoint/ResNet50V2-checkpoint-{epoch:02d}-{val_loss:.2f}.keras',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    verbose=1
)

# %%
# Train the model
epochs = 150

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, tensorboard_callback, checkpoint_callback]
)
# Out:
# Epoch 1/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.2265 - loss: 2.8181
# Epoch 1: val_loss improved from inf to 1.50383, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-01-1.50.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 125s 122ms/step - accuracy: 0.2266 - loss: 2.8175 - val_accuracy: 0.5423 - val_loss: 1.5038
# Epoch 2/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4804 - loss: 1.7279
# Epoch 2: val_loss improved from 1.50383 to 1.28262, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-02-1.28.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - accuracy: 0.4804 - loss: 1.7278 - val_accuracy: 0.6067 - val_loss: 1.2826
# Epoch 3/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5294 - loss: 1.5451
# Epoch 3: val_loss improved from 1.28262 to 1.20046, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-03-1.20.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.5294 - loss: 1.5450 - val_accuracy: 0.6297 - val_loss: 1.2005
# Epoch 4/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5608 - loss: 1.4494
# Epoch 4: val_loss improved from 1.20046 to 1.13757, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-04-1.14.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - accuracy: 0.5608 - loss: 1.4494 - val_accuracy: 0.6491 - val_loss: 1.1376
# Epoch 5/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5719 - loss: 1.3851
# Epoch 5: val_loss improved from 1.13757 to 1.10557, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-05-1.11.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.5719 - loss: 1.3850 - val_accuracy: 0.6604 - val_loss: 1.1056
# Epoch 6/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5918 - loss: 1.3266
# Epoch 6: val_loss improved from 1.10557 to 1.06862, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-06-1.07.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - accuracy: 0.5918 - loss: 1.3265 - val_accuracy: 0.6693 - val_loss: 1.0686
# Epoch 7/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6039 - loss: 1.2909
# Epoch 7: val_loss improved from 1.06862 to 1.04845, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-07-1.05.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6039 - loss: 1.2909 - val_accuracy: 0.6731 - val_loss: 1.0484
# Epoch 8/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6062 - loss: 1.2764
# Epoch 8: val_loss improved from 1.04845 to 1.03839, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-08-1.04.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6062 - loss: 1.2764 - val_accuracy: 0.6776 - val_loss: 1.0384
# Epoch 9/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6157 - loss: 1.2413
# Epoch 9: val_loss improved from 1.03839 to 1.02572, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-09-1.03.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6157 - loss: 1.2412 - val_accuracy: 0.6813 - val_loss: 1.0257
# Epoch 10/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6124 - loss: 1.2385
# Epoch 10: val_loss improved from 1.02572 to 1.00410, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-10-1.00.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.6124 - loss: 1.2384 - val_accuracy: 0.6845 - val_loss: 1.0041
# Epoch 11/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6282 - loss: 1.1974
# Epoch 11: val_loss improved from 1.00410 to 1.00173, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-11-1.00.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6282 - loss: 1.1974 - val_accuracy: 0.6860 - val_loss: 1.0017
# Epoch 12/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6273 - loss: 1.1913
# Epoch 12: val_loss improved from 1.00173 to 0.98608, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-12-0.99.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6273 - loss: 1.1913 - val_accuracy: 0.6903 - val_loss: 0.9861
# Epoch 13/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6325 - loss: 1.1768
# Epoch 13: val_loss improved from 0.98608 to 0.97648, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-13-0.98.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.6325 - loss: 1.1768 - val_accuracy: 0.6915 - val_loss: 0.9765
# Epoch 14/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6344 - loss: 1.1606
# Epoch 14: val_loss improved from 0.97648 to 0.96423, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-14-0.96.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.6344 - loss: 1.1606 - val_accuracy: 0.6936 - val_loss: 0.9642
# Epoch 15/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6404 - loss: 1.1452
# Epoch 15: val_loss did not improve from 0.96423
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6404 - loss: 1.1452 - val_accuracy: 0.6925 - val_loss: 0.9711
# Epoch 16/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6474 - loss: 1.1230
# Epoch 16: val_loss improved from 0.96423 to 0.95290, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-16-0.95.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6474 - loss: 1.1230 - val_accuracy: 0.7007 - val_loss: 0.9529
# Epoch 17/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6474 - loss: 1.1210
# Epoch 17: val_loss improved from 0.95290 to 0.95012, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-17-0.95.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6474 - loss: 1.1210 - val_accuracy: 0.7021 - val_loss: 0.9501
# Epoch 18/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6483 - loss: 1.1153
# Epoch 18: val_loss improved from 0.95012 to 0.94231, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-18-0.94.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6483 - loss: 1.1153 - val_accuracy: 0.7024 - val_loss: 0.9423
# Epoch 19/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6458 - loss: 1.1252
# Epoch 19: val_loss improved from 0.94231 to 0.93817, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-19-0.94.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6459 - loss: 1.1252 - val_accuracy: 0.7029 - val_loss: 0.9382
# Epoch 20/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6570 - loss: 1.0958
# Epoch 20: val_loss improved from 0.93817 to 0.92648, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-20-0.93.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6571 - loss: 1.0958 - val_accuracy: 0.7051 - val_loss: 0.9265
# Epoch 21/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6576 - loss: 1.0861
# Epoch 21: val_loss improved from 0.92648 to 0.92466, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-21-0.92.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6576 - loss: 1.0860 - val_accuracy: 0.7061 - val_loss: 0.9247
# Epoch 22/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6607 - loss: 1.0782
# Epoch 22: val_loss improved from 0.92466 to 0.91936, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-22-0.92.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6607 - loss: 1.0782 - val_accuracy: 0.7093 - val_loss: 0.9194
# Epoch 23/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6612 - loss: 1.0723
# Epoch 23: val_loss improved from 0.91936 to 0.91510, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-23-0.92.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.6612 - loss: 1.0723 - val_accuracy: 0.7067 - val_loss: 0.9151
# Epoch 24/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6664 - loss: 1.0649
# Epoch 24: val_loss did not improve from 0.91510
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6664 - loss: 1.0649 - val_accuracy: 0.7069 - val_loss: 0.9187
# Epoch 25/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6630 - loss: 1.0572
# Epoch 25: val_loss improved from 0.91510 to 0.91129, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-25-0.91.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6630 - loss: 1.0572 - val_accuracy: 0.7117 - val_loss: 0.9113
# Epoch 26/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6631 - loss: 1.0573
# Epoch 26: val_loss did not improve from 0.91129
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6631 - loss: 1.0573 - val_accuracy: 0.7089 - val_loss: 0.9152
# Epoch 27/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6693 - loss: 1.0444
# Epoch 27: val_loss improved from 0.91129 to 0.89740, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-27-0.90.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6693 - loss: 1.0443 - val_accuracy: 0.7143 - val_loss: 0.8974
# Epoch 28/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6740 - loss: 1.0413
# Epoch 28: val_loss did not improve from 0.89740
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6740 - loss: 1.0412 - val_accuracy: 0.7123 - val_loss: 0.9008
# Epoch 29/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6739 - loss: 1.0334
# Epoch 29: val_loss did not improve from 0.89740
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6739 - loss: 1.0333 - val_accuracy: 0.7093 - val_loss: 0.9051
# Epoch 30/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6751 - loss: 1.0330
# Epoch 30: val_loss improved from 0.89740 to 0.89488, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-30-0.89.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6751 - loss: 1.0329 - val_accuracy: 0.7151 - val_loss: 0.8949
# Epoch 31/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6787 - loss: 1.0125
# Epoch 31: val_loss did not improve from 0.89488
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - accuracy: 0.6787 - loss: 1.0125 - val_accuracy: 0.7141 - val_loss: 0.9018
# Epoch 32/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6764 - loss: 1.0101
# Epoch 32: val_loss did not improve from 0.89488
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6764 - loss: 1.0100 - val_accuracy: 0.7101 - val_loss: 0.9101
# Epoch 33/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6799 - loss: 1.0186
# Epoch 33: val_loss did not improve from 0.89488
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6799 - loss: 1.0186 - val_accuracy: 0.7107 - val_loss: 0.9100
# Epoch 34/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6785 - loss: 1.0028
# Epoch 34: val_loss did not improve from 0.89488
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.6785 - loss: 1.0028 - val_accuracy: 0.7168 - val_loss: 0.8954
# Epoch 35/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6820 - loss: 1.0014
# Epoch 35: val_loss improved from 0.89488 to 0.88763, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-35-0.89.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6820 - loss: 1.0014 - val_accuracy: 0.7127 - val_loss: 0.8876
# Epoch 36/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6771 - loss: 1.0112
# Epoch 36: val_loss did not improve from 0.88763
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6772 - loss: 1.0111 - val_accuracy: 0.7148 - val_loss: 0.8885
# Epoch 37/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6881 - loss: 0.9891
# Epoch 37: val_loss improved from 0.88763 to 0.88704, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-37-0.89.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 43ms/step - accuracy: 0.6881 - loss: 0.9891 - val_accuracy: 0.7163 - val_loss: 0.8870
# Epoch 38/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6869 - loss: 0.9855
# Epoch 38: val_loss improved from 0.88704 to 0.87928, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-38-0.88.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6869 - loss: 0.9855 - val_accuracy: 0.7161 - val_loss: 0.8793
# Epoch 39/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6886 - loss: 0.9847
# Epoch 39: val_loss did not improve from 0.87928
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6886 - loss: 0.9847 - val_accuracy: 0.7167 - val_loss: 0.8838
# Epoch 40/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6840 - loss: 0.9870
# Epoch 40: val_loss did not improve from 0.87928
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6840 - loss: 0.9870 - val_accuracy: 0.7143 - val_loss: 0.8855
# Epoch 41/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6844 - loss: 0.9841
# Epoch 41: val_loss improved from 0.87928 to 0.87637, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-41-0.88.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - accuracy: 0.6844 - loss: 0.9841 - val_accuracy: 0.7219 - val_loss: 0.8764
# Epoch 42/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6892 - loss: 0.9790
# Epoch 42: val_loss did not improve from 0.87637
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6892 - loss: 0.9790 - val_accuracy: 0.7208 - val_loss: 0.8806
# Epoch 43/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6925 - loss: 0.9713
# Epoch 43: val_loss did not improve from 0.87637
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6925 - loss: 0.9713 - val_accuracy: 0.7181 - val_loss: 0.8778
# Epoch 44/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6951 - loss: 0.9747
# Epoch 44: val_loss improved from 0.87637 to 0.87576, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-44-0.88.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6951 - loss: 0.9746 - val_accuracy: 0.7223 - val_loss: 0.8758
# Epoch 45/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6924 - loss: 0.9624
# Epoch 45: val_loss did not improve from 0.87576
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6924 - loss: 0.9624 - val_accuracy: 0.7163 - val_loss: 0.8781
# Epoch 46/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6957 - loss: 0.9568
# Epoch 46: val_loss improved from 0.87576 to 0.86971, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-46-0.87.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.6957 - loss: 0.9568 - val_accuracy: 0.7213 - val_loss: 0.8697
# Epoch 47/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6941 - loss: 0.9568
# Epoch 47: val_loss improved from 0.86971 to 0.86330, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-47-0.86.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.6941 - loss: 0.9568 - val_accuracy: 0.7247 - val_loss: 0.8633
# Epoch 48/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7000 - loss: 0.9554
# Epoch 48: val_loss did not improve from 0.86330
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.7000 - loss: 0.9554 - val_accuracy: 0.7224 - val_loss: 0.8745
# Epoch 49/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6955 - loss: 0.9493
# Epoch 49: val_loss did not improve from 0.86330
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - accuracy: 0.6955 - loss: 0.9492 - val_accuracy: 0.7237 - val_loss: 0.8715
# Epoch 50/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7037 - loss: 0.9400
# Epoch 50: val_loss did not improve from 0.86330
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.7037 - loss: 0.9400 - val_accuracy: 0.7181 - val_loss: 0.8741
# Epoch 51/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6975 - loss: 0.9545
# Epoch 51: val_loss did not improve from 0.86330
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - accuracy: 0.6975 - loss: 0.9545 - val_accuracy: 0.7203 - val_loss: 0.8702
# Epoch 52/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6999 - loss: 0.9422
# Epoch 52: val_loss improved from 0.86330 to 0.85975, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-52-0.86.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6999 - loss: 0.9422 - val_accuracy: 0.7256 - val_loss: 0.8598
# Epoch 53/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7052 - loss: 0.9308
# Epoch 53: val_loss did not improve from 0.85975
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.7052 - loss: 0.9308 - val_accuracy: 0.7288 - val_loss: 0.8608
# Epoch 54/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6987 - loss: 0.9415
# Epoch 54: val_loss improved from 0.85975 to 0.85708, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-54-0.86.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.6987 - loss: 0.9415 - val_accuracy: 0.7264 - val_loss: 0.8571
# Epoch 55/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7014 - loss: 0.9451
# Epoch 55: val_loss did not improve from 0.85708
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.7014 - loss: 0.9451 - val_accuracy: 0.7272 - val_loss: 0.8631
# Epoch 56/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7030 - loss: 0.9422
# Epoch 56: val_loss improved from 0.85708 to 0.85356, saving model to /kaggle/working/checkpoint/ResNet50V2-checkpoint-56-0.85.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.7030 - loss: 0.9422 - val_accuracy: 0.7283 - val_loss: 0.8536
# Epoch 57/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7065 - loss: 0.9325
# Epoch 57: val_loss did not improve from 0.85356
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.7065 - loss: 0.9325 - val_accuracy: 0.7228 - val_loss: 0.8658
# Epoch 58/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7013 - loss: 0.9305
# Epoch 58: val_loss did not improve from 0.85356
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.7013 - loss: 0.9305 - val_accuracy: 0.7263 - val_loss: 0.8666
# Epoch 59/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6987 - loss: 0.9366
# Epoch 59: val_loss did not improve from 0.85356
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6987 - loss: 0.9365 - val_accuracy: 0.7244 - val_loss: 0.8636
# Epoch 60/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7121 - loss: 0.9136
# Epoch 60: val_loss did not improve from 0.85356
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.7121 - loss: 0.9136 - val_accuracy: 0.7276 - val_loss: 0.8652
# Epoch 61/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7027 - loss: 0.9277
# Epoch 61: val_loss did not improve from 0.85356
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - accuracy: 0.7027 - loss: 0.9276 - val_accuracy: 0.7251 - val_loss: 0.8687

# %%
# Save the final model (this will be the best model if early stopping is triggered)
model.save_weights('/kaggle/working/final_modelResNet50V2.weights.h5')

# %%
# Attempt to save the model in HDF5 format
path ="/kaggle/working/final_modelResNet50V2"
try:
    model.save(f'{path}.h5')
    print("Model saved successfully in HDF5 format.")
except Exception as e:
    print(f"Failed to save model in HDF5 format: {e}")
    print("Attempting to save model in Keras format...")
    try:
        model.save(f'{path}.keras')
        print("Model saved successfully in Keras format.")
    except Exception as e:
        print(f"Failed to save model in Keras format: {e}")
# Out:
# Failed to save model in HDF5 format: cannot pickle 'module' object
# Attempting to save model in Keras format...
# Model saved successfully in Keras format.

# %%
# Plot training & validation accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Evaluate the model
loss, accuracy = model.evaluate(val_ds)
print(f'Validation Accuracy: {accuracy:.2f}')
print(f'Validation loss: {loss:.2f}')
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.7365 - loss: 0.8352
# Validation Accuracy: 0.73
# Validation loss: 0.85

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Get the true labels and predictions
y_true = np.concatenate([y for x, y in val_ds], axis=0)
y_pred = np.argmax(model.predict(val_ds), axis=-1)

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Classification report
class_report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:\n", class_report)
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step
# Classification Report:
#                             precision    recall  f1-score   support
#
#     Asian-Green-Bee-Eater       0.72      0.77      0.74       300
#       Brown-Headed-Barbet       0.46      0.54      0.49       300
#              Cattle-Egret       0.91      0.89      0.90       300
#         Common-Kingfisher       0.70      0.80      0.75       300
#               Common-Myna       0.79      0.78      0.78       300
#          Common-Rosefinch       0.51      0.57      0.54       300
#         Common-Tailorbird       0.62      0.55      0.58       300
#        Coppersmith-Barbet       0.60      0.62      0.61       300
#            Forest-Wagtail       0.79      0.72      0.75       300
#              Gray-Wagtail       0.76      0.68      0.72       300
#                    Hoopoe       0.85      0.86      0.86       300
#                House-Crow       0.77      0.75      0.76       300
#      Indian-Grey-Hornbill       0.63      0.63      0.63       300
#            Indian-Peacock       0.84      0.81      0.83       300
#              Indian-Pitta       0.83      0.72      0.77       300
#             Indian-Roller       0.76      0.65      0.70       300
#            Jungle-Babbler       0.69      0.76      0.72       300
#          Northern-Lapwing       0.68      0.72      0.70       300
#       Red-Wattled-Lapwing       0.71      0.81      0.75       300
#            Ruddy-Shelduck       0.82      0.85      0.84       300
#            Rufous-Treepie       0.69      0.63      0.66       300
#               Sarus-Crane       0.84      0.81      0.82       300
# White-Breasted-Kingfisher       0.80      0.78      0.79       300
#   White-Breasted-Waterhen       0.72      0.68      0.70       300
#             White-Wagtail       0.83      0.84      0.84       300
#
#                  accuracy                           0.73      7500
#                 macro avg       0.73      0.73      0.73      7500
#              weighted avg       0.73      0.73      0.73      7500
