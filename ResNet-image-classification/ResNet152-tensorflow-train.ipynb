# %% [markdown]
# # ResNet152

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.callbacks import EarlyStopping
import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Ensure GPU is available and set memory growth
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Paths to training and validation data
train_path = "/kaggle/input/indian-birds/Birds_25/train"
val_path = "/kaggle/input/indian-birds/Birds_25/valid"

# %%
# Parameters
img_height, img_width = 128, 128
batch_size = 32

# %%
# Load datasets
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    val_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 30000 files belonging to 25 classes.
# Found 7500 files belonging to 25 classes.

# %%
# Print class names
class_names = train_ds.class_names
print(*class_names)
# Out:
# Asian-Green-Bee-Eater Brown-Headed-Barbet Cattle-Egret Common-Kingfisher Common-Myna Common-Rosefinch Common-Tailorbird Coppersmith-Barbet Forest-Wagtail Gray-Wagtail Hoopoe House-Crow Indian-Grey-Hornbill Indian-Peacock Indian-Pitta Indian-Roller Jungle-Babbler Northern-Lapwing Red-Wattled-Lapwing Ruddy-Shelduck Rufous-Treepie Sarus-Crane White-Breasted-Kingfisher White-Breasted-Waterhen White-Wagtail

# %%
import matplotlib.pyplot as plt

# Get a batch of images and labels from the training dataset
image_batch, label_batch = next(iter(train_ds))

# Define the number of samples to display
num_samples = 25  # Display 25 images (5x5 grid)
plt.figure(figsize=(15, 15))

for i in range(num_samples):
    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")

plt.show()

# %%
# Data augmentation
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

# %%
# Preprocess and optimize data loading
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Define the model
num_classes = len(class_names)

# Define the model
base_model = ResNet152(weights='imagenet', input_shape=(img_height, img_width, 3), include_top=False)
base_model.trainable = False  # Initially freeze the base model
# Build the model
model = models.Sequential([
    layers.Input(shape=(img_height, img_width, 3)),  # Define input shape
    data_augmentation,  # Apply augmentation first
    layers.Rescaling(1./255),  # Then rescale
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.Dense(num_classes, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet152 (Functional)          │ (None, 4, 4, 2048)     │    58,370,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         3,225 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,636,953 (223.68 MB)
#  Trainable params: 265,753 (1.01 MB)
#  Non-trainable params: 58,371,200 (222.67 MB)

# %%
# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# TensorBoard callback for visualization
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    filepath='/kaggle/working/checkpoint/ResNet152-checkpoint-{epoch:02d}-{val_loss:.2f}.keras',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    verbose=1
)

# %%
# Train the model
epochs = 150

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, tensorboard_callback, checkpoint_callback]
)
# Out:
# Epoch 1/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.0702 - loss: 3.2151
# Epoch 1: val_loss improved from inf to 3.04494, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-01-3.04.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 167s 152ms/step - accuracy: 0.0703 - loss: 3.2150 - val_accuracy: 0.1172 - val_loss: 3.0449
# Epoch 2/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.1150 - loss: 3.0222
# Epoch 2: val_loss improved from 3.04494 to 2.97571, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-02-2.98.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 106s 113ms/step - accuracy: 0.1150 - loss: 3.0222 - val_accuracy: 0.1367 - val_loss: 2.9757
# Epoch 3/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.1289 - loss: 2.9714
# Epoch 3: val_loss improved from 2.97571 to 2.92232, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-03-2.92.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 107s 114ms/step - accuracy: 0.1289 - loss: 2.9714 - val_accuracy: 0.1435 - val_loss: 2.9223
# Epoch 4/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1387 - loss: 2.9360
# Epoch 4: val_loss improved from 2.92232 to 2.90525, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-04-2.91.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 138s 110ms/step - accuracy: 0.1387 - loss: 2.9360 - val_accuracy: 0.1533 - val_loss: 2.9052
# Epoch 5/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1504 - loss: 2.9088
# Epoch 5: val_loss did not improve from 2.90525
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.1504 - loss: 2.9088 - val_accuracy: 0.1381 - val_loss: 2.9123
# Epoch 6/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1514 - loss: 2.8925
# Epoch 6: val_loss improved from 2.90525 to 2.87782, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-06-2.88.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 102s 109ms/step - accuracy: 0.1514 - loss: 2.8925 - val_accuracy: 0.1519 - val_loss: 2.8778
# Epoch 7/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1558 - loss: 2.8739
# Epoch 7: val_loss improved from 2.87782 to 2.84560, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-07-2.85.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 102s 109ms/step - accuracy: 0.1558 - loss: 2.8739 - val_accuracy: 0.1699 - val_loss: 2.8456
# Epoch 8/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1565 - loss: 2.8621
# Epoch 8: val_loss improved from 2.84560 to 2.82956, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-08-2.83.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 103s 109ms/step - accuracy: 0.1565 - loss: 2.8621 - val_accuracy: 0.1684 - val_loss: 2.8296
# Epoch 9/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1616 - loss: 2.8532
# Epoch 9: val_loss improved from 2.82956 to 2.82542, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-09-2.83.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.1616 - loss: 2.8532 - val_accuracy: 0.1713 - val_loss: 2.8254
# Epoch 10/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1623 - loss: 2.8421
# Epoch 10: val_loss improved from 2.82542 to 2.80695, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-10-2.81.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 102s 109ms/step - accuracy: 0.1623 - loss: 2.8421 - val_accuracy: 0.1736 - val_loss: 2.8070
# Epoch 11/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1684 - loss: 2.8319
# Epoch 11: val_loss did not improve from 2.80695
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 101s 108ms/step - accuracy: 0.1684 - loss: 2.8319 - val_accuracy: 0.1695 - val_loss: 2.8347
# Epoch 12/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1677 - loss: 2.8274
# Epoch 12: val_loss did not improve from 2.80695
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 101s 108ms/step - accuracy: 0.1677 - loss: 2.8274 - val_accuracy: 0.1760 - val_loss: 2.8232
# Epoch 13/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1678 - loss: 2.8180
# Epoch 13: val_loss did not improve from 2.80695
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 102s 109ms/step - accuracy: 0.1678 - loss: 2.8180 - val_accuracy: 0.1729 - val_loss: 2.8129
# Epoch 14/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1754 - loss: 2.8197
# Epoch 14: val_loss improved from 2.80695 to 2.79440, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-14-2.79.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.1754 - loss: 2.8197 - val_accuracy: 0.1836 - val_loss: 2.7944
# Epoch 15/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1713 - loss: 2.8157
# Epoch 15: val_loss improved from 2.79440 to 2.78333, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-15-2.78.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.1713 - loss: 2.8157 - val_accuracy: 0.1863 - val_loss: 2.7833
# Epoch 16/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1737 - loss: 2.8061
# Epoch 16: val_loss did not improve from 2.78333
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 101s 107ms/step - accuracy: 0.1737 - loss: 2.8061 - val_accuracy: 0.1817 - val_loss: 2.7923
# Epoch 17/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1786 - loss: 2.7977
# Epoch 17: val_loss improved from 2.78333 to 2.76748, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-17-2.77.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.1786 - loss: 2.7977 - val_accuracy: 0.1829 - val_loss: 2.7675
# Epoch 18/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1758 - loss: 2.8009
# Epoch 18: val_loss improved from 2.76748 to 2.75785, saving model to /kaggle/working/checkpoint/ResNet152-checkpoint-18-2.76.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 103s 110ms/step - accuracy: 0.1758 - loss: 2.8009 - val_accuracy: 0.1895 - val_loss: 2.7578
# Epoch 19/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1781 - loss: 2.7965
# Epoch 19: val_loss did not improve from 2.75785
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 140s 108ms/step - accuracy: 0.1781 - loss: 2.7965 - val_accuracy: 0.1841 - val_loss: 2.7794
# Epoch 20/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1765 - loss: 2.7980
# Epoch 20: val_loss did not improve from 2.75785
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 101s 107ms/step - accuracy: 0.1765 - loss: 2.7980 - val_accuracy: 0.1873 - val_loss: 2.7651
# Epoch 21/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1809 - loss: 2.7879
# Epoch 21: val_loss did not improve from 2.75785
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.1809 - loss: 2.7879 - val_accuracy: 0.1827 - val_loss: 2.7827
# Epoch 22/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1769 - loss: 2.7896
# Epoch 22: val_loss did not improve from 2.75785
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 100s 107ms/step - accuracy: 0.1769 - loss: 2.7896 - val_accuracy: 0.1837 - val_loss: 2.7680
# Epoch 23/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1808 - loss: 2.7856
# Epoch 23: val_loss did not improve from 2.75785
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 101s 107ms/step - accuracy: 0.1808 - loss: 2.7856 - val_accuracy: 0.1864 - val_loss: 2.7591

# %%
# Save the final model (this will be the best model if early stopping is triggered)
model.save_weights('/kaggle/working/final_modelResNet152.weights.h5')

# %%
# Attempt to save the model in HDF5 format
path ="/kaggle/working/final_modelResNet152"
try:
    model.save(f'{path}.h5')
    print("Model saved successfully in HDF5 format.")
except Exception as e:
    print(f"Failed to save model in HDF5 format: {e}")
    print("Attempting to save model in Keras format...")
    try:
        model.save(f'{path}.keras')
        print("Model saved successfully in Keras format.")
    except Exception as e:
        print(f"Failed to save model in Keras format: {e}")
# Out:
# Failed to save model in HDF5 format: cannot pickle 'module' object
# Attempting to save model in Keras format...
# Model saved successfully in Keras format.

# %%
# Plot training & validation accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Evaluate the model
loss, accuracy = model.evaluate(val_ds)
print(f'Validation Accuracy: {accuracy:.2f}')
print(f'Validation loss: {loss:.2f}')
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 17s 72ms/step - accuracy: 0.1882 - loss: 2.7578
# Validation Accuracy: 0.19
# Validation loss: 2.76

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Get the true labels and predictions
y_true = np.concatenate([y for x, y in val_ds], axis=0)
y_pred = np.argmax(model.predict(val_ds), axis=-1)

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Classification report
class_report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:\n", class_report)
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 25s 83ms/step
# Classification Report:
#                             precision    recall  f1-score   support
#
#     Asian-Green-Bee-Eater       0.20      0.35      0.26       300
#       Brown-Headed-Barbet       0.14      0.08      0.10       300
#              Cattle-Egret       0.27      0.27      0.27       300
#         Common-Kingfisher       0.19      0.34      0.24       300
#               Common-Myna       0.15      0.04      0.06       300
#          Common-Rosefinch       0.14      0.01      0.02       300
#         Common-Tailorbird       0.18      0.05      0.07       300
#        Coppersmith-Barbet       0.11      0.08      0.09       300
#            Forest-Wagtail       0.25      0.22      0.24       300
#              Gray-Wagtail       0.28      0.06      0.10       300
#                    Hoopoe       0.18      0.28      0.22       300
#                House-Crow       0.18      0.26      0.21       300
#      Indian-Grey-Hornbill       0.25      0.22      0.23       300
#            Indian-Peacock       0.20      0.35      0.26       300
#              Indian-Pitta       0.16      0.08      0.11       300
#             Indian-Roller       0.17      0.13      0.15       300
#            Jungle-Babbler       0.17      0.09      0.12       300
#          Northern-Lapwing       0.22      0.26      0.24       300
#       Red-Wattled-Lapwing       0.19      0.10      0.13       300
#            Ruddy-Shelduck       0.12      0.17      0.14       300
#            Rufous-Treepie       0.22      0.22      0.22       300
#               Sarus-Crane       0.20      0.43      0.27       300
# White-Breasted-Kingfisher       0.16      0.33      0.22       300
#   White-Breasted-Waterhen       0.20      0.11      0.14       300
#             White-Wagtail       0.17      0.21      0.19       300
#
#                  accuracy                           0.19      7500
#                 macro avg       0.19      0.19      0.17      7500
#              weighted avg       0.19      0.19      0.17      7500
