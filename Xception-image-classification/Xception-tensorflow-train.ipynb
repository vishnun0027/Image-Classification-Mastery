# %% [markdown]
# # Xception

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import EarlyStopping
import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2024-08-20 06:55:42.894783: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-20 06:55:42.894939: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-20 06:55:43.034308: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Ensure GPU is available and set memory growth
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Paths to training and validation data
train_path = "/kaggle/input/indian-birds/Birds_25/train"
val_path = "/kaggle/input/indian-birds/Birds_25/valid"

# %%
# Parameters
img_height, img_width = 128, 128
batch_size = 32

# %%
# Load datasets
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    val_path,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 30000 files belonging to 25 classes.
# Found 7500 files belonging to 25 classes.

# %%
# Print class names
class_names = train_ds.class_names
print(*class_names)
# Out:
# Asian-Green-Bee-Eater Brown-Headed-Barbet Cattle-Egret Common-Kingfisher Common-Myna Common-Rosefinch Common-Tailorbird Coppersmith-Barbet Forest-Wagtail Gray-Wagtail Hoopoe House-Crow Indian-Grey-Hornbill Indian-Peacock Indian-Pitta Indian-Roller Jungle-Babbler Northern-Lapwing Red-Wattled-Lapwing Ruddy-Shelduck Rufous-Treepie Sarus-Crane White-Breasted-Kingfisher White-Breasted-Waterhen White-Wagtail

# %%
import matplotlib.pyplot as plt

# Get a batch of images and labels from the training dataset
image_batch, label_batch = next(iter(train_ds))

# Define the number of samples to display
num_samples = 25  # Display 25 images (5x5 grid)
plt.figure(figsize=(15, 15))

for i in range(num_samples):
    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")

plt.show()

# %%
# Data augmentation
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

# %%
# Preprocess and optimize data loading
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Define the model
num_classes = len(class_names)

# Define the model
base_model = Xception(weights='imagenet', input_shape=(img_height, img_width, 3), include_top=False)
base_model.trainable = False  # Initially freeze the base model
# Build the model
model = models.Sequential([
    layers.Input(shape=(img_height, img_width, 3)),  # Define input shape
    data_augmentation,  # Apply augmentation first
    layers.Rescaling(1./255),  # Then rescale
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.Dense(num_classes, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 4, 4, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         3,225 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,127,489 (80.59 MB)
#  Trainable params: 265,753 (1.01 MB)
#  Non-trainable params: 20,861,736 (79.58 MB)

# %%
# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# TensorBoard callback for visualization
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    filepath='/kaggle/working/checkpoint/Xception-checkpoint-{epoch:02d}-{val_loss:.2f}.keras',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    verbose=1
)

# %%
# Train the model
epochs = 150

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, tensorboard_callback, checkpoint_callback]
)
# Out:
# Epoch 1/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.2542 - loss: 2.6570
# Epoch 1: val_loss improved from inf to 1.48257, saving model to /kaggle/working/checkpoint/Xception-checkpoint-01-1.48.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 158s 157ms/step - accuracy: 0.2543 - loss: 2.6565 - val_accuracy: 0.5516 - val_loss: 1.4826
# Epoch 2/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4909 - loss: 1.7147
# Epoch 2: val_loss improved from 1.48257 to 1.27876, saving model to /kaggle/working/checkpoint/Xception-checkpoint-02-1.28.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 52ms/step - accuracy: 0.4910 - loss: 1.7146 - val_accuracy: 0.6103 - val_loss: 1.2788
# Epoch 3/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5381 - loss: 1.5349
# Epoch 3: val_loss improved from 1.27876 to 1.18929, saving model to /kaggle/working/checkpoint/Xception-checkpoint-03-1.19.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.5381 - loss: 1.5349 - val_accuracy: 0.6405 - val_loss: 1.1893
# Epoch 4/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5648 - loss: 1.4469
# Epoch 4: val_loss improved from 1.18929 to 1.14492, saving model to /kaggle/working/checkpoint/Xception-checkpoint-04-1.14.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 52ms/step - accuracy: 0.5648 - loss: 1.4469 - val_accuracy: 0.6517 - val_loss: 1.1449
# Epoch 5/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5714 - loss: 1.4024
# Epoch 5: val_loss improved from 1.14492 to 1.10362, saving model to /kaggle/working/checkpoint/Xception-checkpoint-05-1.10.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 52ms/step - accuracy: 0.5714 - loss: 1.4023 - val_accuracy: 0.6657 - val_loss: 1.1036
# Epoch 6/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5808 - loss: 1.3695
# Epoch 6: val_loss improved from 1.10362 to 1.06685, saving model to /kaggle/working/checkpoint/Xception-checkpoint-06-1.07.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.5808 - loss: 1.3694 - val_accuracy: 0.6771 - val_loss: 1.0668
# Epoch 7/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5949 - loss: 1.3141
# Epoch 7: val_loss improved from 1.06685 to 1.06060, saving model to /kaggle/working/checkpoint/Xception-checkpoint-07-1.06.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.5950 - loss: 1.3141 - val_accuracy: 0.6759 - val_loss: 1.0606
# Epoch 8/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6014 - loss: 1.2896
# Epoch 8: val_loss improved from 1.06060 to 1.03303, saving model to /kaggle/working/checkpoint/Xception-checkpoint-08-1.03.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6014 - loss: 1.2896 - val_accuracy: 0.6832 - val_loss: 1.0330
# Epoch 9/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6103 - loss: 1.2568
# Epoch 9: val_loss improved from 1.03303 to 1.02411, saving model to /kaggle/working/checkpoint/Xception-checkpoint-09-1.02.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6103 - loss: 1.2568 - val_accuracy: 0.6851 - val_loss: 1.0241
# Epoch 10/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6202 - loss: 1.2299
# Epoch 10: val_loss improved from 1.02411 to 1.01269, saving model to /kaggle/working/checkpoint/Xception-checkpoint-10-1.01.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6202 - loss: 1.2299 - val_accuracy: 0.6903 - val_loss: 1.0127
# Epoch 11/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6238 - loss: 1.2237
# Epoch 11: val_loss improved from 1.01269 to 0.99525, saving model to /kaggle/working/checkpoint/Xception-checkpoint-11-1.00.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6238 - loss: 1.2237 - val_accuracy: 0.6913 - val_loss: 0.9953
# Epoch 12/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6220 - loss: 1.2012
# Epoch 12: val_loss improved from 0.99525 to 0.98901, saving model to /kaggle/working/checkpoint/Xception-checkpoint-12-0.99.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6220 - loss: 1.2012 - val_accuracy: 0.6973 - val_loss: 0.9890
# Epoch 13/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6333 - loss: 1.1839
# Epoch 13: val_loss improved from 0.98901 to 0.98418, saving model to /kaggle/working/checkpoint/Xception-checkpoint-13-0.98.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6333 - loss: 1.1839 - val_accuracy: 0.6987 - val_loss: 0.9842
# Epoch 14/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6364 - loss: 1.1704
# Epoch 14: val_loss improved from 0.98418 to 0.97292, saving model to /kaggle/working/checkpoint/Xception-checkpoint-14-0.97.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6364 - loss: 1.1705 - val_accuracy: 0.7028 - val_loss: 0.9729
# Epoch 15/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6337 - loss: 1.1656
# Epoch 15: val_loss improved from 0.97292 to 0.94594, saving model to /kaggle/working/checkpoint/Xception-checkpoint-15-0.95.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6337 - loss: 1.1656 - val_accuracy: 0.7081 - val_loss: 0.9459
# Epoch 16/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6405 - loss: 1.1411
# Epoch 16: val_loss did not improve from 0.94594
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.6405 - loss: 1.1412 - val_accuracy: 0.7072 - val_loss: 0.9544
# Epoch 17/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6416 - loss: 1.1419
# Epoch 17: val_loss did not improve from 0.94594
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.6416 - loss: 1.1419 - val_accuracy: 0.7075 - val_loss: 0.9558
# Epoch 18/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6493 - loss: 1.1223
# Epoch 18: val_loss did not improve from 0.94594
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.6493 - loss: 1.1223 - val_accuracy: 0.7055 - val_loss: 0.9485
# Epoch 19/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6528 - loss: 1.1063
# Epoch 19: val_loss improved from 0.94594 to 0.93879, saving model to /kaggle/working/checkpoint/Xception-checkpoint-19-0.94.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6528 - loss: 1.1063 - val_accuracy: 0.7111 - val_loss: 0.9388
# Epoch 20/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6567 - loss: 1.1069
# Epoch 20: val_loss did not improve from 0.93879
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 51ms/step - accuracy: 0.6567 - loss: 1.1070 - val_accuracy: 0.7104 - val_loss: 0.9459
# Epoch 21/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6521 - loss: 1.0979
# Epoch 21: val_loss improved from 0.93879 to 0.92279, saving model to /kaggle/working/checkpoint/Xception-checkpoint-21-0.92.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 52ms/step - accuracy: 0.6521 - loss: 1.0979 - val_accuracy: 0.7163 - val_loss: 0.9228
# Epoch 22/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6565 - loss: 1.0956
# Epoch 22: val_loss did not improve from 0.92279
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 51ms/step - accuracy: 0.6565 - loss: 1.0957 - val_accuracy: 0.7176 - val_loss: 0.9269
# Epoch 23/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6576 - loss: 1.0877
# Epoch 23: val_loss did not improve from 0.92279
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.6576 - loss: 1.0877 - val_accuracy: 0.7120 - val_loss: 0.9321
# Epoch 24/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6631 - loss: 1.0800
# Epoch 24: val_loss improved from 0.92279 to 0.91978, saving model to /kaggle/working/checkpoint/Xception-checkpoint-24-0.92.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 52ms/step - accuracy: 0.6631 - loss: 1.0800 - val_accuracy: 0.7185 - val_loss: 0.9198
# Epoch 25/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6711 - loss: 1.0585
# Epoch 25: val_loss improved from 0.91978 to 0.91918, saving model to /kaggle/working/checkpoint/Xception-checkpoint-25-0.92.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.6711 - loss: 1.0586 - val_accuracy: 0.7165 - val_loss: 0.9192
# Epoch 26/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6610 - loss: 1.0682
# Epoch 26: val_loss improved from 0.91918 to 0.91482, saving model to /kaggle/working/checkpoint/Xception-checkpoint-26-0.91.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6610 - loss: 1.0682 - val_accuracy: 0.7160 - val_loss: 0.9148
# Epoch 27/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6656 - loss: 1.0653
# Epoch 27: val_loss did not improve from 0.91482
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6656 - loss: 1.0653 - val_accuracy: 0.7172 - val_loss: 0.9191
# Epoch 28/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6636 - loss: 1.0602
# Epoch 28: val_loss improved from 0.91482 to 0.90596, saving model to /kaggle/working/checkpoint/Xception-checkpoint-28-0.91.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6636 - loss: 1.0603 - val_accuracy: 0.7248 - val_loss: 0.9060
# Epoch 29/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6699 - loss: 1.0454
# Epoch 29: val_loss did not improve from 0.90596
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6699 - loss: 1.0454 - val_accuracy: 0.7160 - val_loss: 0.9205
# Epoch 30/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6694 - loss: 1.0505
# Epoch 30: val_loss did not improve from 0.90596
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 51ms/step - accuracy: 0.6694 - loss: 1.0505 - val_accuracy: 0.7217 - val_loss: 0.9182
# Epoch 31/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6756 - loss: 1.0434
# Epoch 31: val_loss did not improve from 0.90596
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6756 - loss: 1.0435 - val_accuracy: 0.7213 - val_loss: 0.9141
# Epoch 32/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6734 - loss: 1.0453
# Epoch 32: val_loss did not improve from 0.90596
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.6734 - loss: 1.0453 - val_accuracy: 0.7204 - val_loss: 0.9067
# Epoch 33/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6754 - loss: 1.0290
# Epoch 33: val_loss improved from 0.90596 to 0.90335, saving model to /kaggle/working/checkpoint/Xception-checkpoint-33-0.90.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 52ms/step - accuracy: 0.6754 - loss: 1.0290 - val_accuracy: 0.7232 - val_loss: 0.9034
# Epoch 34/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6791 - loss: 1.0270
# Epoch 34: val_loss did not improve from 0.90335
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 51ms/step - accuracy: 0.6791 - loss: 1.0271 - val_accuracy: 0.7221 - val_loss: 0.9060
# Epoch 35/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6769 - loss: 1.0299
# Epoch 35: val_loss improved from 0.90335 to 0.89282, saving model to /kaggle/working/checkpoint/Xception-checkpoint-35-0.89.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6769 - loss: 1.0299 - val_accuracy: 0.7217 - val_loss: 0.8928
# Epoch 36/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6742 - loss: 1.0279
# Epoch 36: val_loss improved from 0.89282 to 0.88581, saving model to /kaggle/working/checkpoint/Xception-checkpoint-36-0.89.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6742 - loss: 1.0279 - val_accuracy: 0.7265 - val_loss: 0.8858
# Epoch 37/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6807 - loss: 1.0140
# Epoch 37: val_loss did not improve from 0.88581
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6807 - loss: 1.0140 - val_accuracy: 0.7257 - val_loss: 0.8956
# Epoch 38/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6787 - loss: 1.0099
# Epoch 38: val_loss did not improve from 0.88581
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.6787 - loss: 1.0099 - val_accuracy: 0.7284 - val_loss: 0.8877
# Epoch 39/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6885 - loss: 0.9923
# Epoch 39: val_loss did not improve from 0.88581
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6885 - loss: 0.9923 - val_accuracy: 0.7205 - val_loss: 0.9022
# Epoch 40/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6863 - loss: 0.9899
# Epoch 40: val_loss improved from 0.88581 to 0.87728, saving model to /kaggle/working/checkpoint/Xception-checkpoint-40-0.88.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6863 - loss: 0.9899 - val_accuracy: 0.7284 - val_loss: 0.8773
# Epoch 41/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6812 - loss: 0.9962
# Epoch 41: val_loss did not improve from 0.87728
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6812 - loss: 0.9962 - val_accuracy: 0.7263 - val_loss: 0.8867
# Epoch 42/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6841 - loss: 0.9898
# Epoch 42: val_loss did not improve from 0.87728
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6841 - loss: 0.9898 - val_accuracy: 0.7296 - val_loss: 0.8813
# Epoch 43/150
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6900 - loss: 0.9881
# Epoch 43: val_loss improved from 0.87728 to 0.86966, saving model to /kaggle/working/checkpoint/Xception-checkpoint-43-0.87.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.6900 - loss: 0.9881 - val_accuracy: 0.7332 - val_loss: 0.8697
# Epoch 44/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6810 - loss: 0.9900
# Epoch 44: val_loss did not improve from 0.86966
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.6810 - loss: 0.9900 - val_accuracy: 0.7253 - val_loss: 0.8812
# Epoch 45/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6845 - loss: 0.9915
# Epoch 45: val_loss did not improve from 0.86966
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 51ms/step - accuracy: 0.6845 - loss: 0.9915 - val_accuracy: 0.7328 - val_loss: 0.8747
# Epoch 46/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6915 - loss: 0.9858
# Epoch 46: val_loss did not improve from 0.86966
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 51ms/step - accuracy: 0.6915 - loss: 0.9858 - val_accuracy: 0.7231 - val_loss: 0.8929
# Epoch 47/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6925 - loss: 0.9697
# Epoch 47: val_loss did not improve from 0.86966
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 51ms/step - accuracy: 0.6925 - loss: 0.9697 - val_accuracy: 0.7289 - val_loss: 0.8805
# Epoch 48/150
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6940 - loss: 0.9737
# Epoch 48: val_loss did not improve from 0.86966
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.6940 - loss: 0.9737 - val_accuracy: 0.7279 - val_loss: 0.8720

# %%
# Save the final model (this will be the best model if early stopping is triggered)
model.save_weights('/kaggle/working/final_modelXception.weights.h5')

# %%
# Attempt to save the model in HDF5 format
path ="/kaggle/working/final_modelXception"
try:
    model.save(f'{path}.h5')
    print("Model saved successfully in HDF5 format.")
except Exception as e:
    print(f"Failed to save model in HDF5 format: {e}")
    print("Attempting to save model in Keras format...")
    try:
        model.save(f'{path}.keras')
        print("Model saved successfully in Keras format.")
    except Exception as e:
        print(f"Failed to save model in Keras format: {e}")
# Out:
# Failed to save model in HDF5 format: cannot pickle 'module' object
# Attempting to save model in Keras format...
# Model saved successfully in Keras format.

# %%
# Plot training & validation accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Evaluate the model
loss, accuracy = model.evaluate(val_ds)
print(f'Validation Accuracy: {accuracy:.2f}')
print(f'Validation loss: {loss:.2f}')
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.7279 - loss: 0.8939
# Validation Accuracy: 0.73
# Validation loss: 0.87

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Get the true labels and predictions
y_true = np.concatenate([y for x, y in val_ds], axis=0)
y_pred = np.argmax(model.predict(val_ds), axis=-1)

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Classification report
class_report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:\n", class_report)
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step
# Classification Report:
#                             precision    recall  f1-score   support
#
#     Asian-Green-Bee-Eater       0.71      0.82      0.76       300
#       Brown-Headed-Barbet       0.64      0.55      0.59       300
#              Cattle-Egret       0.89      0.91      0.90       300
#         Common-Kingfisher       0.80      0.78      0.79       300
#               Common-Myna       0.80      0.75      0.78       300
#          Common-Rosefinch       0.61      0.59      0.60       300
#         Common-Tailorbird       0.57      0.57      0.57       300
#        Coppersmith-Barbet       0.61      0.66      0.63       300
#            Forest-Wagtail       0.74      0.71      0.72       300
#              Gray-Wagtail       0.77      0.69      0.73       300
#                    Hoopoe       0.88      0.82      0.85       300
#                House-Crow       0.78      0.75      0.76       300
#      Indian-Grey-Hornbill       0.66      0.63      0.64       300
#            Indian-Peacock       0.75      0.86      0.80       300
#              Indian-Pitta       0.75      0.77      0.76       300
#             Indian-Roller       0.71      0.73      0.72       300
#            Jungle-Babbler       0.74      0.76      0.75       300
#          Northern-Lapwing       0.65      0.74      0.69       300
#       Red-Wattled-Lapwing       0.73      0.68      0.70       300
#            Ruddy-Shelduck       0.85      0.84      0.84       300
#            Rufous-Treepie       0.70      0.65      0.67       300
#               Sarus-Crane       0.83      0.83      0.83       300
# White-Breasted-Kingfisher       0.77      0.73      0.75       300
#   White-Breasted-Waterhen       0.68      0.67      0.67       300
#             White-Wagtail       0.76      0.85      0.80       300
#
#                  accuracy                           0.73      7500
#                 macro avg       0.73      0.73      0.73      7500
#              weighted avg       0.73      0.73      0.73      7500
